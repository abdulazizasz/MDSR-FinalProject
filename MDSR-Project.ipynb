# %% [markdown]
# # Intermediate Report - Preprocessing

# %% [markdown]
# Imports

# %%
# References 

# https://towardsdatascience.com/solving-a-simple-classification-problem-with-python-fruits-lovers-edition-d20ab6b071d2
# https://www.analyticsvidhya.com/blog/2018/04/a-comprehensive-guide-to-understand-and-implement-text-classification-in-python/

# %%
import urllib
import urllib.request
import zipfile
import os
import nltk
import glob
import re
import csv
import time
import random
import sys
from urllib.request import urlopen
import urllib.request, urllib.error
import pandas as pd
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
import pandas, xgboost, numpy, textblob, string
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras import layers, models, optimizers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Load the repository list

# %%
with open('./data/TopStaredRepositories.csv', 'r') as f:
    reader = csv.reader(f)
    templist = list(reader)
repoheader=templist[0]
repolist=templist[1:]
# print(repoheader)

repos=[]
for line in repolist:
    repos.append({'username':line[0],'reponame':line[1],'description':line[2],
                  'updateDate':line[3],'language':line[4],'stars':line[5],'tags':line[6],'url':line[7]})
print(repos[1])
# Out:
# {'username': 'twbs', 'reponame': 'bootstrap', 'description': 'The most popular HTML, CSS, and JavaScript framework for developing responsive, mobile first projects on the web.', 'updateDate': '2017-06-24T15:40:21Z', 'language': 'JavaScript', 'stars': '112k', 'tags': 'javascript,css,html,bootstrap,jekyll-site,scss', 'url': 'https://github.com/twbs/bootstrap'}

# %%
### Read the content of the readme file 


### https://codereview.stackexchange.com/questions/186614/text-cleaning-script-producing-lowercase-words-with-minimal-punctuation

def cleaning(text):
    text = re.sub(r'\b(?:(?:https?|ftp)://)?\w[\w-]*(?:\.[\w-]+)+\S*', ' ', text.lower())
    words = re.findall(r'[a-z]+', text)
    return ' '.join(words)


count = 0
for repo in repos:
    url = "https://raw.githubusercontent.com"+"/"+repo['username']+"/"+repo['reponame']+"/master/README.md"
    try:
        print(url)
        conn = urlopen(url)
        repo['read_me'] = cleaning(conn.read().decode('utf-8'))
        count +=1
    except:
        try:
            url = "https://raw.githubusercontent.com"+"/"+repo['username']+"/"+repo['reponame']+"/master/readme.md"
            conn = urlopen(url)
            repo['read_me'] = cleaning(conn.read().decode('utf-8'))    
        except:
            print("Error in {}".format(repo['reponame']))
            repo['read_me'] = None
            continue
# Out:
# https://raw.githubusercontent.com/freeCodeCamp/freeCodeCamp/master/README.md
# https://raw.githubusercontent.com/twbs/bootstrap/master/README.md
# https://raw.githubusercontent.com/EbookFoundation/free-programming-books/master/README.md
# https://raw.githubusercontent.com/facebook/react/master/README.md
# https://raw.githubusercontent.com/d3/d3/master/README.md
# https://raw.githubusercontent.com/getify/You-Dont-Know-JS/master/README.md
# https://raw.githubusercontent.com/tensorflow/tensorflow/master/README.md
# https://raw.githubusercontent.com/sindresorhus/awesome/master/README.md
# https://raw.githubusercontent.com/vuejs/vue/master/README.md
# https://raw.githubusercontent.com/angular/angular.js/master/README.md
# https://raw.githubusercontent.com/robbyrussell/oh-my-zsh/master/README.md
# https://raw.githubusercontent.com/airbnb/javascript/master/README.md
# https://raw.githubusercontent.com/github/gitignore/master/README.md
# https://raw.githubusercontent.com/FortAwesome/Font-Awesome/master/README.md
# https://raw.githubusercontent.com/facebook/react-native/master/README.md
# https://raw.githubusercontent.com/electron/electron/master/README.md
# https://raw.githubusercontent.com/torvalds/linux/master/README.md
# Error in linux
# https://raw.githubusercontent.com/jquery/jquery/master/README.md
# https://raw.githubusercontent.com/jwasham/coding-interview-university/master/README.md
# https://raw.githubusercontent.com/moby/moby/master/README.md
# https://raw.githubusercontent.com/daneden/animate.css/master/README.md
# https://raw.githubusercontent.com/apple/swift/master/README.md
# https://raw.githubusercontent.com/atom/atom/master/README.md
# https://raw.githubusercontent.com/meteor/meteor/master/README.md
# https://raw.githubusercontent.com/h5bp/html5-boilerplate/master/README.md
# https://raw.githubusercontent.com/nodejs/node/master/README.md
# https://raw.githubusercontent.com/nodejs/node-v0.x-archive/master/README.md
# https://raw.githubusercontent.com/rails/rails/master/README.md
# https://raw.githubusercontent.com/Semantic-Org/Semantic-UI/master/README.md
# https://raw.githubusercontent.com/vinta/awesome-python/master/README.md
# https://raw.githubusercontent.com/hakimel/reveal.js/master/README.md
# https://raw.githubusercontent.com/socketio/socket.io/master/README.md
# Error in socket.io
# https://raw.githubusercontent.com/mrdoob/three.js/master/README.md
# https://raw.githubusercontent.com/laravel/laravel/master/README.md
# https://raw.githubusercontent.com/expressjs/express/master/README.md
# Error in express
# https://raw.githubusercontent.com/reactjs/redux/master/README.md
# https://raw.githubusercontent.com/moment/moment/master/README.md
# https://raw.githubusercontent.com/impress/impress.js/master/README.md
# https://raw.githubusercontent.com/nwjs/nw.js/master/README.md
# https://raw.githubusercontent.com/jlevy/the-art-of-command-line/master/README.md
# https://raw.githubusercontent.com/chartjs/Chart.js/master/README.md
# https://raw.githubusercontent.com/google/material-design-icons/master/README.md
# https://raw.githubusercontent.com/jakubroztocil/httpie/master/README.md
# Error in httpie
# https://raw.githubusercontent.com/ionic-team/ionic/master/README.md
# https://raw.githubusercontent.com/jekyll/jekyll/master/README.md
# Error in jekyll
# https://raw.githubusercontent.com/Microsoft/vscode/master/README.md
# https://raw.githubusercontent.com/webpack/webpack/master/README.md
# https://raw.githubusercontent.com/resume/resume.github.com/master/README.md
# Error in resume.github.com
# https://raw.githubusercontent.com/AFNetworking/AFNetworking/master/README.md
# https://raw.githubusercontent.com/golang/go/master/README.md
# https://raw.githubusercontent.com/facebookincubator/create-react-app/master/README.md
# https://raw.githubusercontent.com/Homebrew/legacy-homebrew/master/README.md
# https://raw.githubusercontent.com/nvbn/thefuck/master/README.md
# https://raw.githubusercontent.com/h5bp/Front-end-Developer-Interview-Questions/master/README.md
# https://raw.githubusercontent.com/pallets/flask/master/README.md
# Error in flask
# https://raw.githubusercontent.com/NARKOZ/hacker-scripts/master/README.md
# https://raw.githubusercontent.com/google/material-design-lite/master/README.md
# https://raw.githubusercontent.com/adobe/brackets/master/README.md
# https://raw.githubusercontent.com/Dogfalo/materialize/master/README.md
# https://raw.githubusercontent.com/blueimp/jQuery-File-Upload/master/README.md
# https://raw.githubusercontent.com/rg3/youtube-dl/master/README.md
# https://raw.githubusercontent.com/necolas/normalize.css/master/README.md
# https://raw.githubusercontent.com/gulpjs/gulp/master/README.md
# https://raw.githubusercontent.com/callemall/material-ui/master/README.md
# https://raw.githubusercontent.com/jashkenas/backbone/master/README.md
# https://raw.githubusercontent.com/django/django/master/README.md
# Error in django
# https://raw.githubusercontent.com/yarnpkg/yarn/master/README.md
# https://raw.githubusercontent.com/requests/requests/master/README.md
# https://raw.githubusercontent.com/zurb/foundation-sites/master/README.md
# https://raw.githubusercontent.com/angular/angular/master/README.md
# https://raw.githubusercontent.com/ReactiveX/RxJava/master/README.md
# Error in RxJava
# https://raw.githubusercontent.com/chrislgarry/Apollo-11/master/README.md
# https://raw.githubusercontent.com/kubernetes/kubernetes/master/README.md
# https://raw.githubusercontent.com/lodash/lodash/master/README.md
# https://raw.githubusercontent.com/Alamofire/Alamofire/master/README.md
# https://raw.githubusercontent.com/antirez/redis/master/README.md
# Error in redis
# https://raw.githubusercontent.com/wasabeef/awesome-android-ui/master/README.md
# https://raw.githubusercontent.com/ansible/ansible/master/README.md
# Error in ansible
# https://raw.githubusercontent.com/getlantern/lantern/master/README.md
# https://raw.githubusercontent.com/josephmisiti/awesome-machine-learning/master/README.md
# https://raw.githubusercontent.com/kamranahmedse/developer-roadmap/master/README.md
# https://raw.githubusercontent.com/papers-we-love/papers-we-love/master/README.md
# https://raw.githubusercontent.com/elastic/elasticsearch/master/README.md
# Error in elasticsearch
# https://raw.githubusercontent.com/Trinea/android-open-project/master/README.md
# https://raw.githubusercontent.com/neovim/neovim/master/README.md
# https://raw.githubusercontent.com/Microsoft/TypeScript/master/README.md
# https://raw.githubusercontent.com/nylas/nylas-mail/master/README.md
# https://raw.githubusercontent.com/ReactTraining/react-router/master/README.md
# https://raw.githubusercontent.com/TryGhost/Ghost/master/README.md
# https://raw.githubusercontent.com/johnpapa/angular-styleguide/master/README.md
# https://raw.githubusercontent.com/typicode/json-server/master/README.md
# https://raw.githubusercontent.com/ariya/phantomjs/master/README.md
# https://raw.githubusercontent.com/open-source-society/computer-science/master/README.md
# https://raw.githubusercontent.com/tiimgreen/github-cheat-sheet/master/README.md
# https://raw.githubusercontent.com/rust-lang/rust/master/README.md
# https://raw.githubusercontent.com/square/retrofit/master/README.md
# https://raw.githubusercontent.com/discourse/discourse/master/README.md
# https://raw.githubusercontent.com/firehol/netdata/master/README.md
# https://raw.githubusercontent.com/dypsilon/frontend-dev-bookmarks/master/README.md
# https://raw.githubusercontent.com/mzabriskie/axios/master/README.md
# https://raw.githubusercontent.com/avelino/awesome-go/master/README.md
# https://raw.githubusercontent.com/caolan/async/master/README.md
# https://raw.githubusercontent.com/babel/babel/master/README.md
# https://raw.githubusercontent.com/tastejs/todomvc/master/README.md
# https://raw.githubusercontent.com/minimaxir/big-list-of-naughty-strings/master/README.md
# https://raw.githubusercontent.com/scrapy/scrapy/master/README.md
# Error in scrapy
# https://raw.githubusercontent.com/jashkenas/underscore/master/README.md
# https://raw.githubusercontent.com/harvesthq/chosen/master/README.md
# https://raw.githubusercontent.com/lukehoban/es6features/master/README.md
# https://raw.githubusercontent.com/Modernizr/Modernizr/master/README.md
# https://raw.githubusercontent.com/square/okhttp/master/README.md
# https://raw.githubusercontent.com/select2/select2/master/README.md
# https://raw.githubusercontent.com/vsouza/awesome-ios/master/README.md
# https://raw.githubusercontent.com/adam-p/markdown-here/master/README.md
# https://raw.githubusercontent.com/sahat/hackathon-starter/master/README.md
# https://raw.githubusercontent.com/enaqx/awesome-react/master/README.md
# https://raw.githubusercontent.com/creationix/nvm/master/README.md
# https://raw.githubusercontent.com/iluwatar/java-design-patterns/master/README.md
# https://raw.githubusercontent.com/prakhar1989/awesome-courses/master/README.md
# https://raw.githubusercontent.com/gogits/gogs/master/README.md
# https://raw.githubusercontent.com/Unitech/pm2/master/README.md
# https://raw.githubusercontent.com/alvarotrigo/fullPage.js/master/README.md
# https://raw.githubusercontent.com/gitlabhq/gitlabhq/master/README.md
# https://raw.githubusercontent.com/karan/Projects/master/README.md
# https://raw.githubusercontent.com/scikit-learn/scikit-learn/master/README.md
# Error in scikit-learn
# https://raw.githubusercontent.com/googlesamples/android-architecture/master/README.md
# https://raw.githubusercontent.com/facebook/immutable-js/master/README.md
# https://raw.githubusercontent.com/rethinkdb/rethinkdb/master/README.md
# Error in rethinkdb
# https://raw.githubusercontent.com/caesar0301/awesome-public-datasets/master/README.md
# Error in awesome-public-datasets
# https://raw.githubusercontent.com/joshbuchea/HEAD/master/README.md
# https://raw.githubusercontent.com/bayandin/awesome-awesomeness/master/README.md
# https://raw.githubusercontent.com/certbot/certbot/master/README.md
# Error in certbot
# https://raw.githubusercontent.com/toddmotto/public-apis/master/README.md
# https://raw.githubusercontent.com/Leaflet/Leaflet/master/README.md
# https://raw.githubusercontent.com/ecomfe/echarts/master/README.md
# https://raw.githubusercontent.com/BVLC/caffe/master/README.md
# https://raw.githubusercontent.com/kenwheeler/slick/master/README.md
# Error in slick
# https://raw.githubusercontent.com/justjavac/free-programming-books-zh_CN/master/README.md
# https://raw.githubusercontent.com/codepath/android_guides/master/README.md
# https://raw.githubusercontent.com/mozilla/pdf.js/master/README.md
# https://raw.githubusercontent.com/FezVrasta/bootstrap-material-design/master/README.md
# https://raw.githubusercontent.com/shadowsocks/shadowsocks/master/README.md
# https://raw.githubusercontent.com/google/protobuf/master/README.md
# https://raw.githubusercontent.com/git/git/master/README.md
# https://raw.githubusercontent.com/gohugoio/hugo/master/README.md
# https://raw.githubusercontent.com/emberjs/ember.js/master/README.md
# https://raw.githubusercontent.com/rs/SDWebImage/master/README.md
# https://raw.githubusercontent.com/Polymer/polymer/master/README.md
# https://raw.githubusercontent.com/zenorocha/clipboard.js/master/README.md
# https://raw.githubusercontent.com/facebook/pop/master/README.md
# https://raw.githubusercontent.com/sindresorhus/awesome-nodejs/master/README.md
# https://raw.githubusercontent.com/tensorflow/models/master/README.md
# https://raw.githubusercontent.com/nvie/gitflow/master/README.md
# Error in gitflow
# https://raw.githubusercontent.com/donnemartin/system-design-primer/master/README.md
# https://raw.githubusercontent.com/zeit/hyper/master/README.md
# https://raw.githubusercontent.com/vuejs/awesome-vue/master/README.md
# https://raw.githubusercontent.com/ReactiveCocoa/ReactiveCocoa/master/README.md
# https://raw.githubusercontent.com/serverless/serverless/master/README.md
# https://raw.githubusercontent.com/balderdashy/sails/master/README.md
# https://raw.githubusercontent.com/plataformatec/devise/master/README.md
# https://raw.githubusercontent.com/kamranahmedse/design-patterns-for-humans/master/README.md
# https://raw.githubusercontent.com/Prinzhorn/skrollr/master/README.md
# https://raw.githubusercontent.com/open-guides/og-aws/master/README.md
# https://raw.githubusercontent.com/google/guava/master/README.md
# https://raw.githubusercontent.com/herrbischoff/awesome-osx-command-line/master/README.md
# https://raw.githubusercontent.com/almasaeed2010/AdminLTE/master/README.md
# https://raw.githubusercontent.com/numbbbbb/the-swift-programming-language-in-chinese/master/README.md
# Error in the-swift-programming-language-in-chinese
# https://raw.githubusercontent.com/yahoo/pure/master/README.md
# https://raw.githubusercontent.com/mathiasbynens/dotfiles/master/README.md
# https://raw.githubusercontent.com/IanLunn/Hover/master/README.md
# https://raw.githubusercontent.com/fchollet/keras/master/README.md
# https://raw.githubusercontent.com/hexojs/hexo/master/README.md
# https://raw.githubusercontent.com/JakeWharton/butterknife/master/README.md
# https://raw.githubusercontent.com/videojs/video.js/master/README.md
# https://raw.githubusercontent.com/google/web-starter-kit/master/README.md
# https://raw.githubusercontent.com/FallibleInc/security-guide-for-developers/master/README.md
# https://raw.githubusercontent.com/fastlane/fastlane/master/README.md
# https://raw.githubusercontent.com/astaxie/build-web-application-with-golang/master/README.md
# https://raw.githubusercontent.com/grafana/grafana/master/README.md
# https://raw.githubusercontent.com/Reactive-Extensions/RxJS/master/README.md
# https://raw.githubusercontent.com/jgthms/bulma/master/README.md
# https://raw.githubusercontent.com/huginn/huginn/master/README.md
# https://raw.githubusercontent.com/hammerjs/hammer.js/master/README.md
# https://raw.githubusercontent.com/opencv/opencv/master/README.md
# https://raw.githubusercontent.com/PhilJay/MPAndroidChart/master/README.md
# https://raw.githubusercontent.com/syncthing/syncthing/master/README.md
# https://raw.githubusercontent.com/Kickball/awesome-selfhosted/master/README.md
# https://raw.githubusercontent.com/railsware/upterm/master/README.md
# https://raw.githubusercontent.com/bumptech/glide/master/README.md
# https://raw.githubusercontent.com/bevacqua/dragula/master/README.md
# Error in dragula
# https://raw.githubusercontent.com/t4t5/sweetalert/master/README.md
# https://raw.githubusercontent.com/koajs/koa/master/README.md
# Error in koa
# https://raw.githubusercontent.com/ripienaar/free-for-dev/master/README.md
# https://raw.githubusercontent.com/request/request/master/README.md
# https://raw.githubusercontent.com/BradLarson/GPUImage/master/README.md
# https://raw.githubusercontent.com/sdmg15/Best-websites-a-programmer-should-visit/master/README.md
# https://raw.githubusercontent.com/ziadoz/awesome-php/master/README.md
# https://raw.githubusercontent.com/aosabook/500lines/master/README.md
# https://raw.githubusercontent.com/square/leakcanary/master/README.md
# https://raw.githubusercontent.com/angular/material/master/README.md
# https://raw.githubusercontent.com/GitbookIO/gitbook/master/README.md
# https://raw.githubusercontent.com/photonstorm/phaser/master/README.md
# https://raw.githubusercontent.com/JetBrains/kotlin/master/README.md
# Error in kotlin
# https://raw.githubusercontent.com/SamyPesse/How-to-Make-a-Computer-Operating-System/master/README.md
# https://raw.githubusercontent.com/verekia/js-stack-from-scratch/master/README.md
# https://raw.githubusercontent.com/usablica/intro.js/master/README.md
# https://raw.githubusercontent.com/nostra13/Android-Universal-Image-Loader/master/README.md
# https://raw.githubusercontent.com/ZuzooVn/machine-learning-for-software-engineers/master/README.md
# https://raw.githubusercontent.com/MaximAbramchuck/awesome-interview-questions/master/README.md
# https://raw.githubusercontent.com/ajaxorg/ace/master/README.md
# Error in ace
# https://raw.githubusercontent.com/postcss/postcss/master/README.md
# https://raw.githubusercontent.com/bower/bower/master/README.md
# https://raw.githubusercontent.com/VundleVim/Vundle.vim/master/README.md
# https://raw.githubusercontent.com/Tencent/weui/master/README.md
# https://raw.githubusercontent.com/defunkt/jquery-pjax/master/README.md
# https://raw.githubusercontent.com/kahun/awesome-sysadmin/master/README.md
# https://raw.githubusercontent.com/SnapKit/Masonry/master/README.md
# https://raw.githubusercontent.com/greenrobot/EventBus/master/README.md
# https://raw.githubusercontent.com/XX-net/XX-Net/master/README.md
# https://raw.githubusercontent.com/pixijs/pixi.js/master/README.md
# https://raw.githubusercontent.com/danielgindi/Charts/master/README.md
# https://raw.githubusercontent.com/ftlabs/fastclick/master/README.md
# https://raw.githubusercontent.com/less/less.js/master/README.md
# https://raw.githubusercontent.com/petkaantonov/bluebird/master/README.md
# https://raw.githubusercontent.com/mitchellh/vagrant/master/README.md
# https://raw.githubusercontent.com/SwiftyJSON/SwiftyJSON/master/README.md
# https://raw.githubusercontent.com/ryanmcdermott/clean-code-javascript/master/README.md
# https://raw.githubusercontent.com/symfony/symfony/master/README.md
# https://raw.githubusercontent.com/github/fetch/master/README.md
# https://raw.githubusercontent.com/ant-design/ant-design/master/README.md
# https://raw.githubusercontent.com/ApacheInfra/superset/master/README.md
# https://raw.githubusercontent.com/lord/slate/master/README.md
# https://raw.githubusercontent.com/pugjs/pug/master/README.md
# https://raw.githubusercontent.com/spring-projects/spring-framework/master/README.md
# https://raw.githubusercontent.com/bcit-ci/CodeIgniter/master/README.md
# Error in CodeIgniter
# https://raw.githubusercontent.com/facebook/hhvm/master/README.md
# https://raw.githubusercontent.com/alex/what-happens-when/master/README.md
# Error in what-happens-when
# https://raw.githubusercontent.com/0xAX/linux-insides/master/README.md
# https://raw.githubusercontent.com/kriasoft/react-starter-kit/master/README.md
# https://raw.githubusercontent.com/alibaba/weex/master/README.md
# https://raw.githubusercontent.com/zeit/next.js/master/README.md
# https://raw.githubusercontent.com/tonsky/FiraCode/master/README.md
# https://raw.githubusercontent.com/twitter/typeahead.js/master/README.md
# https://raw.githubusercontent.com/react-boilerplate/react-boilerplate/master/README.md
# https://raw.githubusercontent.com/angular-ui/bootstrap/master/README.md
# https://raw.githubusercontent.com/dhg/Skeleton/master/README.md
# https://raw.githubusercontent.com/FreeCodeCampChina/freecodecamp.cn/master/README.md
# https://raw.githubusercontent.com/dimsemenov/PhotoSwipe/master/README.md
# https://raw.githubusercontent.com/futurice/android-best-practices/master/README.md
# https://raw.githubusercontent.com/Valloric/YouCompleteMe/master/README.md
# https://raw.githubusercontent.com/zxing/zxing/master/README.md
# https://raw.githubusercontent.com/isocpp/CppCoreGuidelines/master/README.md
# https://raw.githubusercontent.com/jashkenas/coffeescript/master/README.md
# https://raw.githubusercontent.com/jcjohnson/neural-style/master/README.md
# https://raw.githubusercontent.com/facebook/flux/master/README.md
# https://raw.githubusercontent.com/ElemeFE/element/master/README.md
# https://raw.githubusercontent.com/racaljk/hosts/master/README.md
# https://raw.githubusercontent.com/twbs/ratchet/master/README.md
# https://raw.githubusercontent.com/quilljs/quill/master/README.md
# https://raw.githubusercontent.com/coreos/etcd/master/README.md
# https://raw.githubusercontent.com/Bilibili/ijkplayer/master/README.md
# https://raw.githubusercontent.com/rstacruz/nprogress/master/README.md
# Error in nprogress
# https://raw.githubusercontent.com/dokku/dokku/master/README.md
# https://raw.githubusercontent.com/bitcoin/bitcoin/master/README.md
# https://raw.githubusercontent.com/webtorrent/webtorrent/master/README.md
# https://raw.githubusercontent.com/tornadoweb/tornado/master/README.md
# Error in tornado
# https://raw.githubusercontent.com/square/picasso/master/README.md
# https://raw.githubusercontent.com/parse-community/parse-server/master/README.md
# https://raw.githubusercontent.com/dkhamsing/open-source-ios-apps/master/README.md
# https://raw.githubusercontent.com/spring-projects/spring-boot/master/README.md
# Error in spring-boot
# https://raw.githubusercontent.com/airbnb/lottie-android/master/README.md
# https://raw.githubusercontent.com/google/iosched/master/README.md
# https://raw.githubusercontent.com/limetext/lime/master/README.md
# https://raw.githubusercontent.com/soimort/you-get/master/README.md
# https://raw.githubusercontent.com/jdg/MBProgressHUD/master/README.md
# Error in MBProgressHUD
# https://raw.githubusercontent.com/kriskowal/q/master/README.md
# https://raw.githubusercontent.com/tobiasahlin/SpinKit/master/README.md
# https://raw.githubusercontent.com/jaywcjlove/awesome-mac/master/README.md
# https://raw.githubusercontent.com/reddit/reddit/master/README.md
# https://raw.githubusercontent.com/angular-ui/ui-router/master/README.md
# https://raw.githubusercontent.com/jondot/awesome-react-native/master/README.md
# https://raw.githubusercontent.com/apache/spark/master/README.md
# https://raw.githubusercontent.com/Thibaut/devdocs/master/README.md
# https://raw.githubusercontent.com/chjj/marked/master/README.md
# https://raw.githubusercontent.com/knsv/mermaid/master/README.md
# https://raw.githubusercontent.com/juliangarnier/anime/master/README.md
# https://raw.githubusercontent.com/designmodo/Flat-UI/master/README.md
# https://raw.githubusercontent.com/julianshapiro/velocity/master/README.md
# https://raw.githubusercontent.com/akullpp/awesome-java/master/README.md
# https://raw.githubusercontent.com/raywenderlich/swift-algorithm-club/master/README.md
# Error in swift-algorithm-club
# https://raw.githubusercontent.com/postcss/autoprefixer/master/README.md
# https://raw.githubusercontent.com/getsentry/sentry/master/README.md
# Error in sentry
# https://raw.githubusercontent.com/angular/angular-seed/master/README.md
# https://raw.githubusercontent.com/npm/npm/master/README.md
# Error in npm
# https://raw.githubusercontent.com/facebook/fresco/master/README.md
# https://raw.githubusercontent.com/hubotio/hubot/master/README.md
# https://raw.githubusercontent.com/domnikl/DesignPatternsPHP/master/README.md
# https://raw.githubusercontent.com/ReactiveX/RxAndroid/master/README.md
# Error in RxAndroid
# https://raw.githubusercontent.com/rwaldron/idiomatic.js/master/README.md
# https://raw.githubusercontent.com/mholt/caddy/master/README.md
# https://raw.githubusercontent.com/nolimits4web/Swiper/master/README.md
# https://raw.githubusercontent.com/madrobby/zepto/master/README.md
# https://raw.githubusercontent.com/mochajs/mocha/master/README.md
# https://raw.githubusercontent.com/Automattic/mongoose/master/README.md
# https://raw.githubusercontent.com/wg/wrk/master/README.md
# https://raw.githubusercontent.com/ggreer/the_silver_searcher/master/README.md
# https://raw.githubusercontent.com/jlmakes/scrollreveal/master/README.md
# https://raw.githubusercontent.com/jasmine/jasmine/master/README.md
# https://raw.githubusercontent.com/cheeriojs/cheerio/master/README.md
# Error in cheerio
# https://raw.githubusercontent.com/bbatsov/ruby-style-guide/master/README.md
# https://raw.githubusercontent.com/enyo/dropzone/master/README.md
# https://raw.githubusercontent.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/master/README.md
# https://raw.githubusercontent.com/segmentio/nightmare/master/README.md
# Error in nightmare
# https://raw.githubusercontent.com/RocketChat/Rocket.Chat/master/README.md
# https://raw.githubusercontent.com/kripken/emscripten/master/README.md
# https://raw.githubusercontent.com/ruby/ruby/master/README.md
# Error in ruby
# https://raw.githubusercontent.com/interagent/http-api-design/master/README.md
# https://raw.githubusercontent.com/facebook/flow/master/README.md
# https://raw.githubusercontent.com/matteocrippa/awesome-swift/master/README.md
# https://raw.githubusercontent.com/standard/standard/master/README.md
# https://raw.githubusercontent.com/braydie/HowToBeAProgrammer/master/README.md
# https://raw.githubusercontent.com/php/php-src/master/README.md
# https://raw.githubusercontent.com/songrotek/Deep-Learning-Papers-Reading-Roadmap/master/README.md
# https://raw.githubusercontent.com/fouber/blog/master/README.md
# https://raw.githubusercontent.com/twbs/bootstrap-sass/master/README.md
# https://raw.githubusercontent.com/HubSpot/pace/master/README.md
# https://raw.githubusercontent.com/wycats/handlebars.js/master/README.md
# Error in handlebars.js
# https://raw.githubusercontent.com/syl20bnr/spacemacs/master/README.md
# https://raw.githubusercontent.com/riot/riot/master/README.md
# https://raw.githubusercontent.com/codemirror/CodeMirror/master/README.md
# https://raw.githubusercontent.com/dotnet/corefx/master/README.md
# https://raw.githubusercontent.com/aymericdamien/TensorFlow-Examples/master/README.md
# https://raw.githubusercontent.com/ipader/SwiftGuide/master/README.md
# https://raw.githubusercontent.com/desandro/masonry/master/README.md
# https://raw.githubusercontent.com/naptha/tesseract.js/master/README.md
# https://raw.githubusercontent.com/libgdx/libgdx/master/README.md
# https://raw.githubusercontent.com/PerfectlySoft/Perfect/master/README.md
# https://raw.githubusercontent.com/mongodb/mongo/master/README.md
# Error in mongo
# https://raw.githubusercontent.com/legomushroom/mojs/master/README.md
# https://raw.githubusercontent.com/faif/python-patterns/master/README.md
# https://raw.githubusercontent.com/kennethreitz/python-guide/master/README.md
# Error in python-guide
# https://raw.githubusercontent.com/prettier/prettier/master/README.md
# https://raw.githubusercontent.com/kilimchoi/engineering-blogs/master/README.md
# https://raw.githubusercontent.com/facebookarchive/AsyncDisplayKit/master/README.md
# https://raw.githubusercontent.com/ipython/ipython/master/README.md
# Error in ipython
# https://raw.githubusercontent.com/ccgus/fmdb/master/README.md
# Error in fmdb
# https://raw.githubusercontent.com/MostlyAdequate/mostly-adequate-guide/master/README.md
# https://raw.githubusercontent.com/wagerfield/parallax/master/README.md
# https://raw.githubusercontent.com/etsy/statsd/master/README.md
# https://raw.githubusercontent.com/storybooks/storybook/master/README.md
# https://raw.githubusercontent.com/Microsoft/CNTK/master/README.md
# https://raw.githubusercontent.com/oneuijs/You-Dont-Need-jQuery/master/README.md
# https://raw.githubusercontent.com/gruntjs/grunt/master/README.md
# https://raw.githubusercontent.com/node-inspector/node-inspector/master/README.md
# https://raw.githubusercontent.com/drduh/macOS-Security-and-Privacy-Guide/master/README.md
# https://raw.githubusercontent.com/sindresorhus/awesome-electron/master/README.md
# https://raw.githubusercontent.com/puikinsh/gentelella/master/README.md
# https://raw.githubusercontent.com/astaxie/beego/master/README.md
# https://raw.githubusercontent.com/textmate/textmate/master/README.md
# https://raw.githubusercontent.com/altercation/solarized/master/README.md
# https://raw.githubusercontent.com/diaspora/diaspora/master/README.md
# https://raw.githubusercontent.com/bolshchikov/js-must-watch/master/README.md
# https://raw.githubusercontent.com/tesseract-ocr/tesseract/master/README.md
# https://raw.githubusercontent.com/DefinitelyTyped/DefinitelyTyped/master/README.md
# https://raw.githubusercontent.com/caskroom/homebrew-cask/master/README.md
# https://raw.githubusercontent.com/ionic-team/ionicons/master/README.md
# https://raw.githubusercontent.com/remy/nodemon/master/README.md
# https://raw.githubusercontent.com/fzaninotto/Faker/master/README.md
# https://raw.githubusercontent.com/substack/node-browserify/master/README.md
# Error in node-browserify
# https://raw.githubusercontent.com/jiahaog/nativefier/master/README.md
# https://raw.githubusercontent.com/Blankj/AndroidUtilCode/master/README.md
# https://raw.githubusercontent.com/h5bp/Effeckt.css/master/README.md
# https://raw.githubusercontent.com/adobe-fonts/source-code-pro/master/README.md
# https://raw.githubusercontent.com/scottjehl/Respond/master/README.md
# https://raw.githubusercontent.com/terryum/awesome-deep-learning-papers/master/README.md
# https://raw.githubusercontent.com/realm/realm-cocoa/master/README.md
# https://raw.githubusercontent.com/influxdata/influxdb/master/README.md
# https://raw.githubusercontent.com/MengTo/Spring/master/README.md
# https://raw.githubusercontent.com/github/hub/master/README.md
# https://raw.githubusercontent.com/Shopify/dashing/master/README.md
# https://raw.githubusercontent.com/janl/mustache.js/master/README.md
# https://raw.githubusercontent.com/jaredhanson/passport/master/README.md
# https://raw.githubusercontent.com/jmcunningham/AngularJS-Learning/master/README.md
# https://raw.githubusercontent.com/facebook/jest/master/README.md
# https://raw.githubusercontent.com/julycoding/The-Art-Of-Programming-By-July/master/README.md
# Error in The-Art-Of-Programming-By-July
# https://raw.githubusercontent.com/visionmedia/superagent/master/README.md
# Error in superagent
# https://raw.githubusercontent.com/chriskempson/tomorrow-theme/master/README.md
# https://raw.githubusercontent.com/requirejs/requirejs/master/README.md
# https://raw.githubusercontent.com/shadowsocks/shadowsocks-windows/master/README.md
# https://raw.githubusercontent.com/cmderdev/cmder/master/README.md
# https://raw.githubusercontent.com/yabwe/medium-editor/master/README.md
# https://raw.githubusercontent.com/Mashape/kong/master/README.md
# https://raw.githubusercontent.com/mattermost/platform/master/README.md
# https://raw.githubusercontent.com/Mantle/Mantle/master/README.md
# https://raw.githubusercontent.com/jessesquires/JSQMessagesViewController/master/README.md
# https://raw.githubusercontent.com/cockroachdb/cockroach/master/README.md
# https://raw.githubusercontent.com/spf13/spf13-vim/master/README.md
# Error in spf13-vim
# https://raw.githubusercontent.com/angular/angular-cli/master/README.md
# https://raw.githubusercontent.com/Marak/faker.js/master/README.md
# Error in faker.js
# https://raw.githubusercontent.com/CoderMJLee/MJRefresh/master/README.md
# https://raw.githubusercontent.com/avajs/ava/master/README.md
# https://raw.githubusercontent.com/jfeinstein10/SlidingMenu/master/README.md
# https://raw.githubusercontent.com/developit/preact/master/README.md
# https://raw.githubusercontent.com/git-tips/tips/master/README.md
# https://raw.githubusercontent.com/NativeScript/NativeScript/master/README.md
# https://raw.githubusercontent.com/inconshreveable/ngrok/master/README.md
# https://raw.githubusercontent.com/donnemartin/interactive-coding-challenges/master/README.md
# https://raw.githubusercontent.com/loverajoel/jstips/master/README.md
# https://raw.githubusercontent.com/RubaXa/Sortable/master/README.md
# https://raw.githubusercontent.com/cocos2d/cocos2d-x/master/README.md
# Error in cocos2d-x
# https://raw.githubusercontent.com/gin-gonic/gin/master/README.md
# https://raw.githubusercontent.com/infernojs/inferno/master/README.md
# https://raw.githubusercontent.com/chrisbanes/PhotoView/master/README.md
# https://raw.githubusercontent.com/yiisoft/yii2/master/README.md
# https://raw.githubusercontent.com/magicalpanda/MagicalRecord/master/README.md
# https://raw.githubusercontent.com/netty/netty/master/README.md
# https://raw.githubusercontent.com/substack/stream-handbook/master/README.md
# Error in stream-handbook
# https://raw.githubusercontent.com/JacksonTian/fks/master/README.md
# https://raw.githubusercontent.com/elixir-lang/elixir/master/README.md
# https://raw.githubusercontent.com/wsargent/docker-cheat-sheet/master/README.md
# https://raw.githubusercontent.com/jquery/jquery-mobile/master/README.md
# https://raw.githubusercontent.com/vapor/vapor/master/README.md
# https://raw.githubusercontent.com/Netflix/Hystrix/master/README.md
# https://raw.githubusercontent.com/SnapKit/SnapKit/master/README.md
# https://raw.githubusercontent.com/drone/drone/master/README.md
# https://raw.githubusercontent.com/jquery/jquery-ui/master/README.md
# https://raw.githubusercontent.com/nolimits4web/Framework7/master/README.md
# https://raw.githubusercontent.com/sass/sass/master/README.md
# https://raw.githubusercontent.com/gatsbyjs/gatsby/master/README.md
# https://raw.githubusercontent.com/adobe-webplatform/Snap.svg/master/README.md
# https://raw.githubusercontent.com/philipwalton/solved-by-flexbox/master/README.md
# https://raw.githubusercontent.com/octocat/Spoon-Knife/master/README.md
# https://raw.githubusercontent.com/alcatraz/Alcatraz/master/README.md
# https://raw.githubusercontent.com/pandas-dev/pandas/master/README.md
# https://raw.githubusercontent.com/VerbalExpressions/JSVerbalExpressions/master/README.md
# https://raw.githubusercontent.com/fbsamples/f8app/master/README.md
# https://raw.githubusercontent.com/google/guetzli/master/README.md
# https://raw.githubusercontent.com/bang590/JSPatch/master/README.md
# https://raw.githubusercontent.com/wekan/wekan/master/README.md
# https://raw.githubusercontent.com/erikras/react-redux-universal-hot-example/master/README.md
# https://raw.githubusercontent.com/docker/compose/master/README.md
# https://raw.githubusercontent.com/jlund/streisand/master/README.md
# https://raw.githubusercontent.com/loopj/android-async-http/master/README.md
# https://raw.githubusercontent.com/google/styleguide/master/README.md
# Error in styleguide
# https://raw.githubusercontent.com/xdissent/ievms/master/README.md
# https://raw.githubusercontent.com/selectize/selectize.js/master/README.md
# https://raw.githubusercontent.com/amazeui/amazeui/master/README.md
# https://raw.githubusercontent.com/SVProgressHUD/SVProgressHUD/master/README.md
# https://raw.githubusercontent.com/uikit/uikit/master/README.md
# https://raw.githubusercontent.com/phanan/htaccess/master/README.md
# https://raw.githubusercontent.com/browserstate/history.js/master/README.md
# https://raw.githubusercontent.com/uxsolutions/bootstrap-datepicker/master/README.md
# https://raw.githubusercontent.com/foreverjs/forever/master/README.md
# https://raw.githubusercontent.com/phoenixframework/phoenix/master/README.md
# https://raw.githubusercontent.com/airbnb/enzyme/master/README.md
# https://raw.githubusercontent.com/kdn251/interviews/master/README.md
# https://raw.githubusercontent.com/facebookresearch/fastText/master/README.md
# https://raw.githubusercontent.com/jwagner/smartcrop.js/master/README.md
# https://raw.githubusercontent.com/addyosmani/backbone-fundamentals/master/README.md
# https://raw.githubusercontent.com/marcuswestin/store.js/master/README.md
# https://raw.githubusercontent.com/benweet/stackedit/master/README.md
# https://raw.githubusercontent.com/yaronn/blessed-contrib/master/README.md
# https://raw.githubusercontent.com/ReactiveX/RxSwift/master/README.md
# https://raw.githubusercontent.com/rollup/rollup/master/README.md
# https://raw.githubusercontent.com/google/leveldb/master/README.md
# https://raw.githubusercontent.com/aurelia/framework/master/README.md
# https://raw.githubusercontent.com/alebcay/awesome-shell/master/README.md
# https://raw.githubusercontent.com/mobxjs/mobx/master/README.md
# https://raw.githubusercontent.com/DrkSephy/es6-cheatsheet/master/README.md
# https://raw.githubusercontent.com/LightTable/LightTable/master/README.md
# https://raw.githubusercontent.com/Carthage/Carthage/master/README.md
# https://raw.githubusercontent.com/facebook/prepack/master/README.md
# https://raw.githubusercontent.com/capistrano/capistrano/master/README.md
# https://raw.githubusercontent.com/cubiq/iscroll/master/README.md
# https://raw.githubusercontent.com/Developer-Y/cs-video-courses/master/README.md
# https://raw.githubusercontent.com/nsqio/nsq/master/README.md
# https://raw.githubusercontent.com/gionkunz/chartist-js/master/README.md
# https://raw.githubusercontent.com/AllThingsSmitty/css-protips/master/README.md
# https://raw.githubusercontent.com/servo/servo/master/README.md
# https://raw.githubusercontent.com/imathis/octopress/master/README.md
# Error in octopress
# https://raw.githubusercontent.com/tootsuite/mastodon/master/README.md
# https://raw.githubusercontent.com/tldr-pages/tldr/master/README.md
# https://raw.githubusercontent.com/mysqljs/mysql/master/README.md
# Error in mysql
# https://raw.githubusercontent.com/petehunt/webpack-howto/master/README.md
# https://raw.githubusercontent.com/rbenv/rbenv/master/README.md
# https://raw.githubusercontent.com/composer/composer/master/README.md
# https://raw.githubusercontent.com/thedillonb/CodeHub/master/README.md
# https://raw.githubusercontent.com/sampotts/plyr/master/README.md
# https://raw.githubusercontent.com/keen/dashboards/master/README.md
# https://raw.githubusercontent.com/markerikson/react-redux-links/master/README.md
# https://raw.githubusercontent.com/cjwirth/awesome-ios-ui/master/README.md
# https://raw.githubusercontent.com/hashicorp/consul/master/README.md
# https://raw.githubusercontent.com/CocoaPods/CocoaPods/master/README.md
# https://raw.githubusercontent.com/amix/vimrc/master/README.md
# https://raw.githubusercontent.com/alibaba/fastjson/master/README.md
# https://raw.githubusercontent.com/playframework/playframework/master/README.md
# https://raw.githubusercontent.com/nicklockwood/iCarousel/master/README.md
# https://raw.githubusercontent.com/lgvalle/Material-Animations/master/README.md
# https://raw.githubusercontent.com/dimsemenov/Magnific-Popup/master/README.md
# https://raw.githubusercontent.com/go-martini/martini/master/README.md
# https://raw.githubusercontent.com/androidannotations/androidannotations/master/README.md
# https://raw.githubusercontent.com/ViccAlexander/Chameleon/master/README.md
# https://raw.githubusercontent.com/localForage/localForage/master/README.md
# https://raw.githubusercontent.com/donnemartin/data-science-ipython-notebooks/master/README.md
# https://raw.githubusercontent.com/vim/vim/master/README.md
# https://raw.githubusercontent.com/angular/material2/master/README.md
# https://raw.githubusercontent.com/sinatra/sinatra/master/README.md
# https://raw.githubusercontent.com/Bilibili/flv.js/master/README.md
# https://raw.githubusercontent.com/vim-airline/vim-airline/master/README.md
# https://raw.githubusercontent.com/alsotang/node-lessons/master/README.md
# https://raw.githubusercontent.com/equinusocio/material-theme/master/README.md
# https://raw.githubusercontent.com/parkjs814/AlgorithmVisualizer/master/README.md
# Error in AlgorithmVisualizer
# https://raw.githubusercontent.com/guzzle/guzzle/master/README.md
# https://raw.githubusercontent.com/WordPress/WordPress/master/README.md
# Error in WordPress
# https://raw.githubusercontent.com/junegunn/fzf/master/README.md
# https://raw.githubusercontent.com/ruanyf/jstraining/master/README.md
# https://raw.githubusercontent.com/lkzhao/Hero/master/README.md
# https://raw.githubusercontent.com/facebook/osquery/master/README.md
# https://raw.githubusercontent.com/buunguyen/octotree/master/README.md
# https://raw.githubusercontent.com/GoogleChrome/lighthouse/master/README.md
# https://raw.githubusercontent.com/hackiftekhar/IQKeyboardManager/master/README.md
# https://raw.githubusercontent.com/sorrycc/awesome-javascript/master/README.md
# https://raw.githubusercontent.com/chenglou/react-motion/master/README.md
# https://raw.githubusercontent.com/FormidableLabs/webpack-dashboard/master/README.md
# https://raw.githubusercontent.com/WickyNilliams/headroom.js/master/README.md
# https://raw.githubusercontent.com/strongloop/loopback/master/README.md
# https://raw.githubusercontent.com/begriffs/postgrest/master/README.md
# https://raw.githubusercontent.com/chrissimpkins/Hack/master/README.md
# https://raw.githubusercontent.com/tpope/vim-pathogen/master/README.md
# Error in vim-pathogen
# https://raw.githubusercontent.com/php-fig/fig-standards/master/README.md
# https://raw.githubusercontent.com/CocoaLumberjack/CocoaLumberjack/master/README.md
# https://raw.githubusercontent.com/scottjehl/picturefill/master/README.md
# https://raw.githubusercontent.com/Tencent/tinker/master/README.md
# https://raw.githubusercontent.com/lukasz-madon/awesome-remote-job/master/README.md
# https://raw.githubusercontent.com/davezuko/react-redux-starter-kit/master/README.md
# https://raw.githubusercontent.com/google/gson/master/README.md
# https://raw.githubusercontent.com/DmitryBaranovskiy/raphael/master/README.md
# https://raw.githubusercontent.com/alibaba/dubbo/master/README.md
# https://raw.githubusercontent.com/ptmt/react-native-macos/master/README.md
# https://raw.githubusercontent.com/nickbutcher/plaid/master/README.md
# https://raw.githubusercontent.com/stedolan/jq/master/README.md
# https://raw.githubusercontent.com/hemanth/functional-programming-jargon/master/README.md
# https://raw.githubusercontent.com/luanfujun/deep-photo-styletransfer/master/README.md
# https://raw.githubusercontent.com/gorhill/uBlock/master/README.md
# https://raw.githubusercontent.com/hzlzh/Best-App/master/README.md
# https://raw.githubusercontent.com/google/fonts/master/README.md
# https://raw.githubusercontent.com/geekcompany/ResumeSample/master/README.md
# https://raw.githubusercontent.com/peachananr/onepage-scroll/master/README.md
# https://raw.githubusercontent.com/thomaspark/bootswatch/master/README.md
# https://raw.githubusercontent.com/facebook/relay/master/README.md
# https://raw.githubusercontent.com/pouchdb/pouchdb/master/README.md
# https://raw.githubusercontent.com/JakeWharton/ViewPagerIndicator/master/README.md
# https://raw.githubusercontent.com/binux/pyspider/master/README.md
# https://raw.githubusercontent.com/petehunt/react-howto/master/README.md
# https://raw.githubusercontent.com/airbnb/lottie-ios/master/README.md
# https://raw.githubusercontent.com/sindresorhus/quick-look-plugins/master/README.md
# https://raw.githubusercontent.com/Tencent/mars/master/README.md
# https://raw.githubusercontent.com/nathanmarz/storm/master/README.md
# Error in storm
# https://raw.githubusercontent.com/PHPMailer/PHPMailer/master/README.md
# https://raw.githubusercontent.com/allenwong/30DaysofSwift/master/README.md
# https://raw.githubusercontent.com/rapid7/metasploit-framework/master/README.md
# https://raw.githubusercontent.com/you-dont-need/You-Dont-Need-JavaScript/master/README.md
# Error in You-Dont-Need-JavaScript
# https://raw.githubusercontent.com/fxsjy/jieba/master/README.md
# https://raw.githubusercontent.com/HubSpot/youmightnotneedjquery/master/README.md
# Error in youmightnotneedjquery
# https://raw.githubusercontent.com/jgm/pandoc/master/README.md
# https://raw.githubusercontent.com/reactnativecn/react-native-guide/master/README.md
# https://raw.githubusercontent.com/abhishekbanthia/Public-APIs/master/README.md
# https://raw.githubusercontent.com/android10/Android-CleanArchitecture/master/README.md
# https://raw.githubusercontent.com/gabrielecirulli/2048/master/README.md
# https://raw.githubusercontent.com/BrowserSync/browser-sync/master/README.md
# https://raw.githubusercontent.com/Automattic/wp-calypso/master/README.md
# https://raw.githubusercontent.com/sqlmapproject/sqlmap/master/README.md
# https://raw.githubusercontent.com/JohnCoates/Aerial/master/README.md
# Error in Aerial
# https://raw.githubusercontent.com/marcuswestin/WebViewJavascriptBridge/master/README.md
# https://raw.githubusercontent.com/Hack-with-Github/Awesome-Hacking/master/README.md
# https://raw.githubusercontent.com/pockethub/PocketHub/master/README.md
# https://raw.githubusercontent.com/onevcat/Kingfisher/master/README.md
# https://raw.githubusercontent.com/jessepollak/card/master/README.md
# https://raw.githubusercontent.com/JuliaLang/julia/master/README.md
# https://raw.githubusercontent.com/robbiehanson/CocoaAsyncSocket/master/README.md
# Error in CocoaAsyncSocket
# https://raw.githubusercontent.com/facebook/folly/master/README.md
# https://raw.githubusercontent.com/fgnass/spin.js/master/README.md
# https://raw.githubusercontent.com/dzenbot/DZNEmptyDataSet/master/README.md
# https://raw.githubusercontent.com/paularmstrong/normalizr/master/README.md
# https://raw.githubusercontent.com/nagadomi/waifu2x/master/README.md
# https://raw.githubusercontent.com/hashicorp/terraform/master/README.md
# https://raw.githubusercontent.com/karma-runner/karma/master/README.md
# https://raw.githubusercontent.com/fabric/fabric/master/README.md
# Error in fabric
# https://raw.githubusercontent.com/pingcap/tidb/master/README.md
# https://raw.githubusercontent.com/maxwellito/vivus/master/README.md
# https://raw.githubusercontent.com/fffaraz/awesome-cpp/master/README.md
# https://raw.githubusercontent.com/xgrommx/awesome-redux/master/README.md
# https://raw.githubusercontent.com/yeoman/yeoman/master/README.md
# https://raw.githubusercontent.com/sdelements/lets-chat/master/README.md
# https://raw.githubusercontent.com/janpaepke/ScrollMagic/master/README.md
# https://raw.githubusercontent.com/thoughtbot/paperclip/master/README.md
# https://raw.githubusercontent.com/PHPOffice/PHPExcel/master/README.md
# https://raw.githubusercontent.com/niklasvh/html2canvas/master/README.md
# https://raw.githubusercontent.com/bailicangdu/vue2-elm/master/README.md
# https://raw.githubusercontent.com/containous/traefik/master/README.md
# https://raw.githubusercontent.com/kevinzhow/PNChart/master/README.md
# https://raw.githubusercontent.com/phacility/phabricator/master/README.md
# https://raw.githubusercontent.com/brillout/awesome-react-components/master/README.md
# https://raw.githubusercontent.com/keon/algorithms/master/README.md
# https://raw.githubusercontent.com/powerline/fonts/master/README.md
# Error in fonts
# https://raw.githubusercontent.com/redux-saga/redux-saga/master/README.md
# https://raw.githubusercontent.com/spree/spree/master/README.md
# https://raw.githubusercontent.com/kesenhoo/android-training-course-in-chinese/master/README.md
# https://raw.githubusercontent.com/ramda/ramda/master/README.md
# https://raw.githubusercontent.com/godotengine/godot/master/README.md
# https://raw.githubusercontent.com/roots/sage/master/README.md
# https://raw.githubusercontent.com/imakewebthings/waypoints/master/README.md
# https://raw.githubusercontent.com/leereilly/games/master/README.md
# https://raw.githubusercontent.com/scala/scala/master/README.md
# Error in scala
# https://raw.githubusercontent.com/crystal-lang/crystal/master/README.md
# https://raw.githubusercontent.com/ty4z2008/Qix/master/README.md
# https://raw.githubusercontent.com/fullstackio/FlappySwift/master/README.md
# Error in FlappySwift
# https://raw.githubusercontent.com/revel/revel/master/README.md
# https://raw.githubusercontent.com/AHAAAAAAA/PokemonGo-Map/master/README.md
# https://raw.githubusercontent.com/onevcat/VVDocumenter-Xcode/master/README.md
# https://raw.githubusercontent.com/python/cpython/master/README.md
# Error in cpython
# https://raw.githubusercontent.com/NUKnightLab/TimelineJS/master/README.md
# Error in TimelineJS
# https://raw.githubusercontent.com/daylerees/colour-schemes/master/README.md
# https://raw.githubusercontent.com/swagger-api/swagger-ui/master/README.md
# https://raw.githubusercontent.com/google/flexbox-layout/master/README.md
# https://raw.githubusercontent.com/tj/co/master/README.md
# Error in co
# https://raw.githubusercontent.com/MrRio/jsPDF/master/README.md
# https://raw.githubusercontent.com/tpope/vim-fugitive/master/README.md
# Error in vim-fugitive
# https://raw.githubusercontent.com/iissnan/hexo-theme-next/master/README.md
# https://raw.githubusercontent.com/oxford-cs-deepnlp-2017/lectures/master/README.md
# https://raw.githubusercontent.com/Microsoft/dotnet/master/README.md
# https://raw.githubusercontent.com/systemjs/systemjs/master/README.md
# https://raw.githubusercontent.com/gollum/gollum/master/README.md
# https://raw.githubusercontent.com/airyland/vux/master/README.md
# https://raw.githubusercontent.com/metafizzy/isotope/master/README.md
# https://raw.githubusercontent.com/AngularClass/angular-starter/master/README.md
# https://raw.githubusercontent.com/thejameskyle/the-super-tiny-compiler/master/README.md
# https://raw.githubusercontent.com/vuejs/vuex/master/README.md
# https://raw.githubusercontent.com/so-fancy/diff-so-fancy/master/README.md
# https://raw.githubusercontent.com/knockout/knockout/master/README.md
# https://raw.githubusercontent.com/bmorelli25/Become-A-Full-Stack-Web-Developer/master/README.md
# https://raw.githubusercontent.com/aFarkas/html5shiv/master/README.md
# https://raw.githubusercontent.com/navasmdc/MaterialDesignLibrary/master/README.md
# https://raw.githubusercontent.com/carhartl/jquery-cookie/master/README.md
# https://raw.githubusercontent.com/chrisbanes/Android-PullToRefresh/master/README.md
# https://raw.githubusercontent.com/hehonghui/android-tech-frontier/master/README.md
# https://raw.githubusercontent.com/Rochester-NRT/RocAlphaGo/master/README.md
# https://raw.githubusercontent.com/reactjs/react-redux/master/README.md
# https://raw.githubusercontent.com/irungentoo/toxcore/master/README.md
# https://raw.githubusercontent.com/stylus/stylus/master/README.md
# ...
# https://raw.githubusercontent.com/zenorocha/alfred-workflows/master/README.md
# https://raw.githubusercontent.com/Automattic/_s/master/README.md
# https://raw.githubusercontent.com/facebookarchive/three20/master/README.md
# Error in three20
# https://raw.githubusercontent.com/ejci/favico.js/master/README.md
# https://raw.githubusercontent.com/gothinkster/realworld/master/README.md
# https://raw.githubusercontent.com/carrierwaveuploader/carrierwave/master/README.md
# https://raw.githubusercontent.com/google/WebFundamentals/master/README.md
# https://raw.githubusercontent.com/nicolargo/glances/master/README.md
# Error in glances
# https://raw.githubusercontent.com/elastic/kibana/master/README.md
# https://raw.githubusercontent.com/datasciencemasters/go/master/README.md
# https://raw.githubusercontent.com/mishoo/UglifyJS/master/README.md
# Error in UglifyJS
# https://raw.githubusercontent.com/danialfarid/ng-file-upload/master/README.md
# https://raw.githubusercontent.com/DrKLO/Telegram/master/README.md
# https://raw.githubusercontent.com/FFmpeg/FFmpeg/master/README.md
# https://raw.githubusercontent.com/cmusatyalab/openface/master/README.md
# https://raw.githubusercontent.com/kamens/jQuery-menu-aim/master/README.md
# https://raw.githubusercontent.com/mwaterfall/MWPhotoBrowser/master/README.md
# https://raw.githubusercontent.com/docker/kitematic/master/README.md
# https://raw.githubusercontent.com/piwik/piwik/master/README.md
# https://raw.githubusercontent.com/WebAssembly/design/master/README.md
# https://raw.githubusercontent.com/laravel/framework/master/README.md
# https://raw.githubusercontent.com/mrmrs/colors/master/README.md
# https://raw.githubusercontent.com/path/FastImageCache/master/README.md
# https://raw.githubusercontent.com/veggiemonk/awesome-docker/master/README.md
# https://raw.githubusercontent.com/ConnorAtherton/loaders.css/master/README.md
# https://raw.githubusercontent.com/reactjs/reselect/master/README.md
# https://raw.githubusercontent.com/activeadmin/activeadmin/master/README.md
# https://raw.githubusercontent.com/marmelab/gremlins.js/master/README.md
# https://raw.githubusercontent.com/buger/goreplay/master/README.md
# https://raw.githubusercontent.com/geeeeeeeeek/electronic-wechat/master/README.md
# https://raw.githubusercontent.com/JakeWharton/ActionBarSherlock/master/README.md
# https://raw.githubusercontent.com/chinchang/hint.css/master/README.md
# https://raw.githubusercontent.com/purifycss/purifycss/master/README.md
# https://raw.githubusercontent.com/karpathy/convnetjs/master/README.md
# Error in convnetjs
# https://raw.githubusercontent.com/NodeBB/NodeBB/master/README.md
# https://raw.githubusercontent.com/uNetworking/uWebSockets/master/README.md
# https://raw.githubusercontent.com/Ramotion/animated-tab-bar/master/README.md
# https://raw.githubusercontent.com/EnterpriseQualityCoding/FizzBuzzEnterpriseEdition/master/README.md
# https://raw.githubusercontent.com/markets/awesome-ruby/master/README.md
# https://raw.githubusercontent.com/nodejitsu/node-http-proxy/master/README.md
# https://raw.githubusercontent.com/rstacruz/jquery.transit/master/README.md
# https://raw.githubusercontent.com/google/traceur-compiler/master/README.md
# https://raw.githubusercontent.com/jhipster/generator-jhipster/master/README.md
# https://raw.githubusercontent.com/carlhuda/janus/master/README.md
# https://raw.githubusercontent.com/HubSpot/tether/master/README.md
# https://raw.githubusercontent.com/hdodenhof/CircleImageView/master/README.md
# https://raw.githubusercontent.com/dropbox/zxcvbn/master/README.md
# https://raw.githubusercontent.com/jacomyal/sigma.js/master/README.md
# https://raw.githubusercontent.com/svg/svgo/master/README.md
# https://raw.githubusercontent.com/css-modules/css-modules/master/README.md
# https://raw.githubusercontent.com/philipwalton/flexbugs/master/README.md
# https://raw.githubusercontent.com/jshint/jshint/master/README.md
# https://raw.githubusercontent.com/matthieua/WOW/master/README.md
# https://raw.githubusercontent.com/winterbe/java8-tutorial/master/README.md
# https://raw.githubusercontent.com/relax/relax/master/README.md
# https://raw.githubusercontent.com/akka/akka/master/README.md
# https://raw.githubusercontent.com/raywenderlich/swift-style-guide/master/README.md
# Error in swift-style-guide
# https://raw.githubusercontent.com/dthree/cash/master/README.md
# https://raw.githubusercontent.com/senchalabs/connect/master/README.md
# https://raw.githubusercontent.com/ocornut/imgui/master/README.md
# Error in imgui
# https://raw.githubusercontent.com/apple/swift-evolution/master/README.md
# https://raw.githubusercontent.com/mozilla-mobile/firefox-ios/master/README.md
# https://raw.githubusercontent.com/PowerShell/PowerShell/master/README.md
# https://raw.githubusercontent.com/spotify/luigi/master/README.md
# Error in luigi
# https://raw.githubusercontent.com/minio/minio/master/README.md
# https://raw.githubusercontent.com/ruanyf/es6tutorial/master/README.md
# Error in es6tutorial
# https://raw.githubusercontent.com/home-assistant/home-assistant/master/README.md
# Error in home-assistant
# https://raw.githubusercontent.com/mxgmn/WaveFunctionCollapse/master/README.md
# https://raw.githubusercontent.com/kkga/spacegray/master/README.md
# https://raw.githubusercontent.com/cakephp/cakephp/master/README.md
# https://raw.githubusercontent.com/FredrikNoren/ungit/master/README.md
# https://raw.githubusercontent.com/mozilla/BrowserQuest/master/README.md
# https://raw.githubusercontent.com/marionettejs/backbone.marionette/master/README.md
# https://raw.githubusercontent.com/javan/whenever/master/README.md
# https://raw.githubusercontent.com/connors/photon/master/README.md
# https://raw.githubusercontent.com/rkt/rkt/master/README.md
# https://raw.githubusercontent.com/go-kit/kit/master/README.md
# https://raw.githubusercontent.com/redox-os/redox/master/README.md
# https://raw.githubusercontent.com/clojure/clojurescript/master/README.md
# https://raw.githubusercontent.com/nosir/cleave.js/master/README.md
# https://raw.githubusercontent.com/realm/SwiftLint/master/README.md
# https://raw.githubusercontent.com/celery/celery/master/README.md
# Error in celery
# https://raw.githubusercontent.com/CRYTEK/CRYENGINE/master/README.md
# Error in CRYENGINE
# https://raw.githubusercontent.com/babun/babun/master/README.md
# Error in babun
# https://raw.githubusercontent.com/tj/n/master/README.md
# https://raw.githubusercontent.com/getgrav/grav/master/README.md
# https://raw.githubusercontent.com/akveo/blur-admin/master/README.md
# https://raw.githubusercontent.com/google/ExoPlayer/master/README.md
# Error in ExoPlayer
# https://raw.githubusercontent.com/kataras/iris/master/README.md
# https://raw.githubusercontent.com/philc/vimium/master/README.md
# https://raw.githubusercontent.com/FineUploader/fine-uploader/master/README.md
# https://raw.githubusercontent.com/torch/torch7/master/README.md
# https://raw.githubusercontent.com/serbanghita/Mobile-Detect/master/README.md
# https://raw.githubusercontent.com/Aufree/trip-to-iOS/master/README.md
# https://raw.githubusercontent.com/CoderMJLee/MJExtension/master/README.md
# https://raw.githubusercontent.com/hashicorp/vault/master/README.md
# https://raw.githubusercontent.com/getpelican/pelican/master/README.md
# Error in pelican
# https://raw.githubusercontent.com/reactide/reactide/master/README.md
# https://raw.githubusercontent.com/gaearon/react-hot-loader/master/README.md
# https://raw.githubusercontent.com/graphql/graphql-js/master/README.md
# https://raw.githubusercontent.com/mailpile/Mailpile/master/README.md
# https://raw.githubusercontent.com/romaonthego/RESideMenu/master/README.md
# https://raw.githubusercontent.com/atech/postal/master/README.md
# https://raw.githubusercontent.com/Compass/compass/master/README.md
# Error in compass
# https://raw.githubusercontent.com/amsul/pickadate.js/master/README.md
# https://raw.githubusercontent.com/douglascrockford/JSON-js/master/README.md
# Error in JSON-js
# https://raw.githubusercontent.com/mailcheck/mailcheck/master/README.md
# https://raw.githubusercontent.com/hakimel/Ladda/master/README.md
# https://raw.githubusercontent.com/TeamStuQ/skill-map/master/README.md
# https://raw.githubusercontent.com/dangrossman/bootstrap-daterangepicker/master/README.md
# https://raw.githubusercontent.com/facebook/infer/master/README.md
# https://raw.githubusercontent.com/c3js/c3/master/README.md
# https://raw.githubusercontent.com/arduino/Arduino/master/README.md
# https://raw.githubusercontent.com/rupa/z/master/README.md
# Error in z
# https://raw.githubusercontent.com/twitter/twemproxy/master/README.md
# https://raw.githubusercontent.com/odoo/odoo/master/README.md
# https://raw.githubusercontent.com/deeplearning4j/deeplearning4j/master/README.md
# https://raw.githubusercontent.com/restify/node-restify/master/README.md
# https://raw.githubusercontent.com/SeleniumHQ/selenium/master/README.md
# https://raw.githubusercontent.com/facebook/SocketRocket/master/README.md
# https://raw.githubusercontent.com/tmux/tmux/master/README.md
# Error in tmux
# https://raw.githubusercontent.com/coryhouse/react-slingshot/master/README.md
# https://raw.githubusercontent.com/getredash/redash/master/README.md
# https://raw.githubusercontent.com/CodeSeven/toastr/master/README.md
# https://raw.githubusercontent.com/fullcalendar/fullcalendar/master/README.md
# https://raw.githubusercontent.com/zeit/pkg/master/README.md
# https://raw.githubusercontent.com/mishoo/UglifyJS2/master/README.md
# https://raw.githubusercontent.com/fronteed/icheck/master/README.md
# Error in icheck
# https://raw.githubusercontent.com/CEWendel/SWTableViewCell/master/README.md
# https://raw.githubusercontent.com/iview/iview/master/README.md
# https://raw.githubusercontent.com/seajs/seajs/master/README.md
# https://raw.githubusercontent.com/ReactiveX/rxjs/master/README.md
# https://raw.githubusercontent.com/cjbarber/ToolsOfTheTrade/master/README.md
# https://raw.githubusercontent.com/hangtwenty/dive-into-machine-learning/master/README.md
# https://raw.githubusercontent.com/giakki/uncss/master/README.md
# https://raw.githubusercontent.com/chrisbanes/cheesesquare/master/README.md
# https://raw.githubusercontent.com/boot2docker/boot2docker/master/README.md
# https://raw.githubusercontent.com/libuv/libuv/master/README.md
# https://raw.githubusercontent.com/feathersjs/feathers/master/README.md
# https://raw.githubusercontent.com/fatih/vim-go/master/README.md
# https://raw.githubusercontent.com/dexteryy/spellbook-of-modern-webdev/master/README.md
# https://raw.githubusercontent.com/facebook/nuclide/master/README.md
# https://raw.githubusercontent.com/breakwa11/shadowsocks-rss/master/README.md
# Error in shadowsocks-rss
# https://raw.githubusercontent.com/tmuxinator/tmuxinator/master/README.md
# https://raw.githubusercontent.com/orhanobut/logger/master/README.md
# https://raw.githubusercontent.com/alexjc/neural-enhance/master/README.md
# Error in neural-enhance
# https://raw.githubusercontent.com/mhinz/vim-galore/master/README.md
# https://raw.githubusercontent.com/hpneo/gmaps/master/README.md
# https://raw.githubusercontent.com/guarinogabriel/Mac-CLI/master/README.md
# https://raw.githubusercontent.com/angular/protractor/master/README.md
# https://raw.githubusercontent.com/casperjs/casperjs/master/README.md
# https://raw.githubusercontent.com/bendc/frontend-guidelines/master/README.md
# https://raw.githubusercontent.com/shekhargulati/52-technologies-in-2016/master/README.md
# https://raw.githubusercontent.com/erikras/redux-form/master/README.md
# https://raw.githubusercontent.com/plataformatec/simple_form/master/README.md
# https://raw.githubusercontent.com/FelisCatus/SwitchyOmega/master/README.md
# https://raw.githubusercontent.com/vurtun/nuklear/master/README.md
# Error in nuklear
# https://raw.githubusercontent.com/hashicorp/packer/master/README.md
# https://raw.githubusercontent.com/mozilla/metrics-graphics/master/README.md
# https://raw.githubusercontent.com/255kb/stack-on-a-budget/master/README.md
# https://raw.githubusercontent.com/louischatriot/nedb/master/README.md
# https://raw.githubusercontent.com/Famous/famous/master/README.md
# https://raw.githubusercontent.com/alibaba/druid/master/README.md
# https://raw.githubusercontent.com/ubuwaits/beautiful-web-type/master/README.md
# Error in beautiful-web-type
# https://raw.githubusercontent.com/StackExchange/Dapper/master/README.md
# Error in Dapper
# https://raw.githubusercontent.com/Mango/slideout/master/README.md
# https://raw.githubusercontent.com/sitaramc/gitolite/master/README.md
# Error in gitolite
# https://raw.githubusercontent.com/cyclejs/cyclejs/master/README.md
# https://raw.githubusercontent.com/OAI/OpenAPI-Specification/master/README.md
# https://raw.githubusercontent.com/h4cc/awesome-elixir/master/README.md
# https://raw.githubusercontent.com/git-up/GitUp/master/README.md
# https://raw.githubusercontent.com/flightjs/flight/master/README.md
# https://raw.githubusercontent.com/nightwatchjs/nightwatch/master/README.md
# https://raw.githubusercontent.com/h2o/h2o/master/README.md
# https://raw.githubusercontent.com/nlp-compromise/compromise/master/README.md
# https://raw.githubusercontent.com/xing/wysihtml5/master/README.md
# Error in wysihtml5
# https://raw.githubusercontent.com/twitter/twemoji/master/README.md
# https://raw.githubusercontent.com/google/agera/master/README.md
# https://raw.githubusercontent.com/bazelbuild/bazel/master/README.md
# https://raw.githubusercontent.com/thoughtbot/guides/master/README.md
# https://raw.githubusercontent.com/howdyai/botkit/master/README.md
# https://raw.githubusercontent.com/kaminari/kaminari/master/README.md
# https://raw.githubusercontent.com/rasbt/python-machine-learning-book/master/README.md
# https://raw.githubusercontent.com/Quick/Quick/master/README.md
# https://raw.githubusercontent.com/sferik/rails_admin/master/README.md
# https://raw.githubusercontent.com/NaturalNode/natural/master/README.md
# https://raw.githubusercontent.com/SignalR/SignalR/master/README.md
# https://raw.githubusercontent.com/morrisjs/morris.js/master/README.md
# https://raw.githubusercontent.com/akveo/ng2-admin/master/README.md
# https://raw.githubusercontent.com/aFarkas/lazysizes/master/README.md
# https://raw.githubusercontent.com/tuupola/jquery_lazyload/master/README.md
# https://raw.githubusercontent.com/maxogden/art-of-node/master/README.md
# https://raw.githubusercontent.com/CachetHQ/Cachet/master/README.md
# https://raw.githubusercontent.com/alexa/alexa-avs-sample-app/master/README.md
# https://raw.githubusercontent.com/Theano/Theano/master/README.md
# Error in Theano
# https://raw.githubusercontent.com/jigish/slate/master/README.md
# https://raw.githubusercontent.com/jp9000/obs-studio/master/README.md
# Error in obs-studio
# https://raw.githubusercontent.com/desandro/imagesloaded/master/README.md
# https://raw.githubusercontent.com/react-toolbox/react-toolbox/master/README.md
# https://raw.githubusercontent.com/Microsoft/api-guidelines/master/README.md
# https://raw.githubusercontent.com/nikitavoloboev/learn-anything/master/README.md
# https://raw.githubusercontent.com/rethinkdb/horizon/master/README.md
# https://raw.githubusercontent.com/Kotlin/anko/master/README.md
# https://raw.githubusercontent.com/PureLayout/PureLayout/master/README.md
# https://raw.githubusercontent.com/roughike/BottomBar/master/README.md
# https://raw.githubusercontent.com/mdo/code-guide/master/README.md
# Error in code-guide
# https://raw.githubusercontent.com/google/python-fire/master/README.md
# https://raw.githubusercontent.com/mobile-shell/mosh/master/README.md
# https://raw.githubusercontent.com/bodymovin/bodymovin/master/README.md
# https://raw.githubusercontent.com/thoughtbot/laptop/master/README.md
# https://raw.githubusercontent.com/boltdb/bolt/master/README.md
# https://raw.githubusercontent.com/braziljs/js-the-right-way/master/README.md
# https://raw.githubusercontent.com/plotly/plotly.js/master/README.md
# https://raw.githubusercontent.com/poteto/hiring-without-whiteboards/master/README.md
# https://raw.githubusercontent.com/chrisjenx/Calligraphy/master/README.md
# https://raw.githubusercontent.com/eliangcs/http-prompt/master/README.md
# Error in http-prompt
# https://raw.githubusercontent.com/robertdavidgraham/masscan/master/README.md
# https://raw.githubusercontent.com/ElemeFE/mint-ui/master/README.md
# https://raw.githubusercontent.com/lhc70000/iina/master/README.md

# %% [markdown]
# Download and unzip the repositories, with sleep added to avoid putting too much pressure on the website.
#
# Some repositories without a master branch will not be downloaded.

# %%
print(count)
# Out:
# 835

# %%
# https://stackoverflow.com/questions/17839973/constructing-pandas-dataframe-from-values-in-variables-gives-valueerror-if-usi
df = pd.DataFrame.from_dict(repos)

# %%
df
# Out:
#                                          description language  \
# 0                         Slim Framework source code      PHP
# 1  An opinionated framework for creating REST-lik...     Ruby
#
#                                              read_me reponame stars  \
# 0                                               None     Slim  8.1k
# 1  grape logo gem version build status dependency...    grape    8k
#
#              tags            updateDate                                  url  \
# 0                  2017-06-19T22:25:10Z      https://github.com/slimphp/Slim
# 1  ruby,api,grape  2017-06-21T21:31:46Z  https://github.com/ruby-grape/grape
#
#      username
# 0     slimphp
# 1  ruby-grape

# %%
df.to_csv(".data/Final_dataset.csv", sep='\t')

# %% [markdown]
# ### NOW WITH STEP 2 ###
#     Preporcessing for ML Models

# %%
dataset = pd.read_csv("./data/Final_dataset.csv", sep='\t')

# %%
dataset.shape
# Out:
# (980, 10)

# %%
sum(pd.isnull(dataset['language']))
# Out:
# 103

# %%
sum(pd.isna(dataset['language']))
# Out:
# 103

# %%
# dataset[pd.isna(dataset['language'])]

# %%
# Let's test it on a smal dataset 

# Used only the useful attributes 
columns = ['description', 'language', 'read_me', 'reponame', 'tags', 'username']
df = dataset[columns]

# %%
df[:2]
# Out:
#                                          description    language  \
# 0  The https://freeCodeCamp.com open source codeb...  JavaScript
# 1  The most popular HTML, CSS, and JavaScript fra...  JavaScript
#
#                                              read_me      reponame  \
# 0  social banner build status pull requests welco...  freeCodeCamp
# 1  bootstrap slack bower version npm version buil...     bootstrap
#
#                                                 tags      username
# 0  nonprofits,certification,curriculum,react,node...  freeCodeCamp
# 1     javascript,css,html,bootstrap,jekyll-site,scss          twbs

# %%
df['collection'] = df[['description','read_me', 'reponame', 'tags', 'username']].apply(lambda x: ' '.join(x.astype(str)), axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df = pd.DataFrame()
new_df['language'] = df['language']
new_df['collection'] = df['collection']

# %%
new_df.to_csv('./data/language_Dataset.csv')

# %%
new_df_lang = new_df[pd.notna(new_df['language'])]

# %%
len(new_df_lang[pd.isnull(new_df_lang['language'])]) == 0
# Out:
# True

# %%
len(new_df_lang)
# Out:
# 877

# %%
new_df_lang.columns
# Out:
# Index(['language', 'collection'], dtype='object')

# %%
# Now let's split the dataset into training and testing datasets 
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(new_df_lang['collection'], new_df_lang['language'])

# %%
print(len(train_x))
print(len(valid_x))
print(len(train_y))
print(len(valid_y))
# Out:
# 657
# 220
# 657
# 220

# %%
# Encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

# %%
# Feature Engineering 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')

count_vect.fit(new_df_lang['collection'])

xtrain_count = count_vect.fit_transform(train_x)
xvalid_count = count_vect.fit_transform(valid_x)

# %%
# TF-IDF Vectors 

# Word Level TF_IDF
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(new_df_lang['collection'])

xtrain_tfidf = tfidf_vect.transform(train_x)
xvalid_tfidf = tfidf_vect.transform(valid_x)

# ngram Level TF_IDF
tfidf_vect_ngram = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram.fit(new_df_lang['collection'])

xtrain_tfidf_ngram = tfidf_vect_ngram.transform(train_x)
xvalid_tfidf_ngram = tfidf_vect_ngram.transform(valid_x)

# Character Level tf_idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(new_df_lang['collection'])

xtrain_tfidf_ngram_chars = tfidf_vect_ngram_chars.transform(train_x)
xvalid_tfidf_ngram_chars = tfidf_vect_ngram_chars.transform(valid_x)

# %%
#  Utility 

def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    print(predictions)
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_y)

# %%
# Naive Bayes on Word Level TF- IDF Vectors 
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y,
                xvalid_tfidf)
print("NB, World TF-IDF Vectors {}".format(accuracy))
# Out:
# [14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14]
# NB, World TF-IDF Vectors 0.004545454545454545

# %%
# Naive Bayes on Ngram Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram,
                      train_y, xvalid_tfidf_ngram)
print("NB, World N-Gram Vectors {}".format(accuracy))
# Out:
# [14 14 14 14 14 14 14 14 14 14 14 14 14 14 27 14 14 14 14 14 14 14 14 14
#  14 14 14 13 14 14 14 14 14 14 14 14 14 14 14 14 13 14 13 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 13 14 14 14 14 14 14 14 14 14 13 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 13 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 13 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14]
# NB, World N-Gram Vectors 0.004545454545454545

# %%
# Naive Bayes on Character Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram_chars,
                      train_y, xvalid_tfidf_ngram_chars)
print("NB, Char Vectors {}".format(accuracy))
# Out:
# [14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14]
# NB, Char Vectors 0.004545454545454545

# %%
#  SVM on NGRAM Level TF IDF Vectors 
accuracy = train_model(svm.SVC(), xtrain_tfidf_ngram, train_y, 
                       xvalid_tfidf_ngram)

print("SVM, N-Gram Vectors {}".format(accuracy))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14 14
#  14 14 14 14]
# SVM, N-Gram Vectors 0.004545454545454545
